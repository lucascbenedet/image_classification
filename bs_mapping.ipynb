# %%
import numpy as np
import pandas as pd
from elasticsearch import Elasticsearch

# %%
#elasticsearch-reset-password -u elastic master
elastic_client = Elasticsearch(hosts=['http://localhost:9200'], 
                               basic_auth=('elastic', 'master'))

# %%
#index_name='bs_index'
index_name='bs_index_full'

# %%
mapping = {
    #"_source": {"excludes": ["embedding"]},
    "properties": {
      "no":    { "type": "text", "index": False },  
      "class_label":    { "type": "keyword", "index": False },  
      "class_id":    { "type": "keyword", "index": False },  
      "name":  { "type": "text", "index": False  }, 
      "embedding":   { "type": "dense_vector", "dims": 512, "index": True, "similarity": "cosine" }
    }
  }
elastic_client.indices.create(index=index_name, mappings=mapping)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'bs_index_full'})

# %%
elastic_client.indices.refresh(index=index_name)
elastic_client.cat.count(index=index_name, format="json")
# Out:
# ListApiResponse([{'epoch': '1705702162', 'timestamp': '22:09:22', 'count': '1136'}])

# %%
for index in elastic_client.indices.get(index='*'):
  print("Index -> ", index)
  print(elastic_client.indices.stats(index=index))
# Out:
# Index ->  bs_index
# ...

# %%
#Executar somente se o índice já estiver criado e for neessário recriá-lo
elastic_client.indices.delete(index=index_name)
# Out:
# ObjectApiResponse({'acknowledged': True})
