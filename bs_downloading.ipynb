# %%
import requests
import numpy as np
import pandas as pd
# Out:
# The kernel failed to start as '_psutil_linux' could not be imported from 'most likely due to a circular import'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
def downloading_url(image_url, output_path, output_image):
    #image_data = requests.get(image_url).content
    with open(output_path+"/"+output_image, 'wb') as handler:
        handler.write(requests.get(image_url).content)

# %%
low_memory=False
ds = pd.read_csv('datasets/full/sb_original.csv')
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1435 entries, 0 to 1434
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   foto                1435 non-null   object
#  1   padrao_construtivo  1435 non-null   object
#  2   class_id            1435 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 33.8+ KB

# %%
ds
# Out:
#                                                    foto padrao_construtivo  \
# 0     https://geo-criciuma-fotos.s3-us-east-2.amazon...               Alto
# 1     https://geo-criciuma-fotos.s3-us-east-2.amazon...               Alto
# 2     https://geo-criciuma-fotos.s3-us-east-2.amazon...               Alto
# 3     https://geo-criciuma-fotos.s3-us-east-2.amazon...               Alto
# 4     https://geo-criciuma-fotos.s3-us-east-2.amazon...               Alto
# ...                                                 ...                ...
# 1430  https://geo-criciuma-fotos.s3-us-east-2.amazon...        Médio Baixo
# 1431  https://geo-criciuma-fotos.s3-us-east-2.amazon...        Médio Baixo
# 1432  https://geo-criciuma-fotos.s3-us-east-2.amazon...        Médio Baixo
# 1433  https://geo-criciuma.s3-sa-east-1.amazonaws.co...        Médio Baixo
# 1434  https://geo-criciuma.s3-sa-east-1.amazonaws.co...        Médio Baixo
#
#       class_id
# 0            1
# 1            1
# 2            1
# ...

# %%
#Transforma o campo embedding para uma lista e armazena em uma lista
result = []
output_path = 'dataset/full/images'
#ctr = 0
for index, row in ds.iterrows():
  #if (ctr > 1289):
    image = row.foto.split('/')[-1]
    print('file:', image, row.foto)
    downloading_url(row.foto, output_path, image)
  #ctr += 1
# Out:
# file: 22_1568748464878.jpg https://geo-criciuma-fotos.s3-us-east-2.amazonaws.com/files/imoveis/3084026/22_1568748464878.jpg
# file: 19_1568748414435.jpg https://geo-criciuma-fotos.s3-us-east-2.amazonaws.com/files/imoveis/3084068/19_1568748414435.jpg
# file: foto_fachada_1607520413880.jpg https://geo-criciuma-fotos.s3-us-east-2.amazonaws.com/files/imoveis/3127415/foto_fachada_1607520413880.jpg
# file: foto_fachada_1607519632406.jpg https://geo-criciuma-fotos.s3-us-east-2.amazonaws.com/files/imoveis/3127956/foto_fachada_1607519632406.jpg
# file: 3_1566841842607.jpg https://geo-criciuma-fotos.s3-us-east-2.amazonaws.com/files/imoveis/3128572/3_1566841842607.jpg
# file: 3_1567772294355.jpg https://geo-criciuma-fotos.s3-us-east-2.amazonaws.com/files/imoveis/3129944/3_1567772294355.jpg
# file: 9_1567772386130.jpg https://geo-criciuma-fotos.s3-us-east-2.amazonaws.com/files/imoveis/3129974/9_1567772386130.jpg
# ...

# %%
image_url = 'https://geo-criciuma-fotos.s3-us-east-2.amazonaws.com/files/imoveis/3036186/20190326_104354_1553629804442.jpg'
output_path = 'datasets/sb/images'
image = image_url.split('/')[-1]
print('file:', image, image_url)
downloading_url(image_url, output_path, image)
# Out:
# file: 20190326_104354_1553629804442.jpg https://geo-criciuma-fotos.s3-us-east-2.amazonaws.com/files/imoveis/3036186/20190326_104354_1553629804442.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 5
#       3 image = image_url.split('/')[-1]
#       4 print('file:', image, image_url)
# ----> 5 downloading_url(image_url, output_path, image)
#
# Cell In[7], line 3, in downloading_url(image_url, output_path, output_image)
#       1 def downloading_url(image_url, output_path, output_image):
#       2     #image_data = requests.get(image_url).content
# ----> 3     with open(output_path+"/"+output_image, 'wb') as handler:
#       4         handler.write(requests.get(image_url).content)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
# ...
